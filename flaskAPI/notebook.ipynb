# %%
import os
import time

import threading
import concurrent.futures
import subprocess as sp

# %%
import json

data = [ { 'a':'A', 'b':(2, 4), 'c':3.0 } ]

# %%
data
# Out:
# [{'a': 'A', 'b': (2, 4), 'c': 3.0}]

# %%
data[0]['version'] = 1.0

data
# Out:
# [{'a': 'A', 'b': (2, 4), 'c': 3.0, 'version': 1.0}]

# %%
os.getcwd()
# Out:
# '/home/onos/Downloads/flaskSDN/flaskAPI'

# %%
sp.run(['python3 ./temp/temp.py'], universal_newlines=True, check=True, shell=True, stdout=sp.PIPE).stdout
# Out:
# 'hello\n'

# %%
PROGRAM_LIST = [
    {
        "name": "example2.py",
        "path": "/run",
        "config": ""
    },
    {
        "name": "app.py",
        "path": "/api",
        "config": "" 
    },
    {
        "name": "uppdateWeight.py",
        "path": "/api",
        "config": ""
    }
]

# %%
PROGRAM_LIST[0]
a = PROGRAM_LIST[0]['path'] + \
PROGRAM_LIST[0]['name']

# %%
a
# Out:
# '/runexample2.py'
