# %%
# read each line of the file 
# Interval       Transfer     Bandwidth        Jitter   Lost/Total Datagrams
import pandas as pd

# create a dataframe 
df_final = []
with open('serverh7.txt') as file_in:
    for line in file_in:
        list_col = line.split()
        if list_col[0] == '[SUM]':
            # new_df = { 'Transfer': list_col[4], 'Bandwidth': list_col[6], 'Jitter': list_col[8], 'Lost': list_col[10], 'Total': list_col[9], 'Datagrams': list_col[10] }
            # print(list_col)
            # if list_col[0][-1] == '-':
            if len(list_col) == 13:
                new_df =  [float(list_col[4]), float(list_col[6]), float(list_col[8]), float(list_col[10][:-1]), float(list_col[11]), float(list_col[12][1:-2]) ]
            elif len(list_col) == 12:
                new_df = [float(list_col[3]), float(list_col[5]), float(list_col[7]),  float(list_col[9][:-1]), float(list_col[10]), float(list_col[11][1:-2])]
            else:
                continue
            df_final.append(new_df)

# %%
import time
import sys

# def update_server():
#     output(sys.argv[1])

# from __future__ import print_function
def follow(thefile):
    thefile.seek(0,2)
    while True:
        line = thefile.readline()
        if not line:
            time.sleep(0.5)
            continue
        yield line

def output(file):
    logfile = open(file)
    loglines = follow(logfile)
    for line in loglines:
        print(line, end='')
        list_col = line.split()
        if list_col[0] == '[SUM]':
            # new_df = { 'Transfer': list_col[4], 'Bandwidth': list_col[6], 'Jitter': list_col[8], 'Lost': list_col[10], 'Total': list_col[9], 'Datagrams': list_col[10] }
            # print(list_col)
            # if list_col[0][-1] == '-':
            if len(list_col) == 13:
                new_df =  [float(list_col[4]), float(list_col[6]), float(list_col[8]), float(list_col[10][:-1]), float(list_col[11]), float(list_col[12][1:-2]) ]
            elif len(list_col) == 12:
                new_df = [float(list_col[3]), float(list_col[5]), float(list_col[7]),  float(list_col[9][:-1]), float(list_col[10]), float(list_col[11][1:-2])]
            else:
                continue
            # df_final.append(new_df)
            print(new_df)
            
    logfile.close()
# output(sys.argv[1])
output("test.txt")
# Out:
# [SUM] 552.0-553.0 sec  1.11 MBytes  9.28 Mbits/sec   0.559 ms  883/ 1672 (53%)
# [1.11, 9.28, 0.559, 883.0, 1672.0, 53.0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-112db284c91f> in <module>
#      38     logfile.close()
#      39 # output(sys.argv[1])
# ---> 40 output("test.txt")
#
# <ipython-input-1-112db284c91f> in output(file)
#      20     logfile = open(file)
#      21     loglines = follow(logfile)
# ---> 22     for line in loglines:
#      23         print(line, end='')
#      24         list_col = line.split()
#
# <ipython-input-1-112db284c91f> in follow(thefile)
#      14         line = thefile.readline()
#      15         if not line:
# ---> 16             time.sleep(0.5)
#      17             continue
#      18         yield line
#
# KeyboardInterrupt:

# %%
def get_BW_from_server(file_name, name_host):
    results = []
    with open(file_name) as file_in:
        for line in file_in:
            list_col = line.split()
            if list_col[0] == '[SUM]':
                # new_df = { 'Transfer': list_col[4], 'Bandwidth': list_col[6], 'Jitter': list_col[8], 'Lost': list_col[10],'Total': list_col[9], 'Datagrams': list_col[10] }
                # print(list_col)
                # if list_col[0][-1] == '-':
                if len(list_col) == 13:
                    results.append( {"NameHost":name_host,"Bandwidth":float(list_col[6])})
                    # new_df =  [float(list_col[4]), float(list_col[6]), float(list_col[8]), float(list_col[10][:-1]), float(list_co[11]), float(list_col[12][1:-2]) ]
                elif len(list_col) == 12:
                    results.append( {"NameHost":name_host,"Bandwidth":float(list_col[5])})
                    # new_df = [float(list_col[3]), float(list_col[5]), float(list_col[7]),  float(list_col[9][:-1]), float(list_co[10]), float(list_col[11][1:-2])]
                else:
                    continue
        return results

# %%
sys.path.append('/home/onos/Downloads/flask_SDN/Flask-SDN/flaskAPI/model')
import BW_server

# %%
list_BW = get_BW_from_server('test.txt', 'h3')

# %%
list_BW
# Out:
# [{'NameHost': 'h3', 'Bandwidth': 5.97},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 9.21},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 9.16},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 7.02},
#  {'NameHost': 'h3', 'Bandwidth': 6.42},
#  {'NameHost': 'h3', 'Bandwidth': 6.54},
#  {'NameHost': 'h3', 'Bandwidth': 6.53},
#  {'NameHost': 'h3', 'Bandwidth': 8.69},
#  {'NameHost': 'h3', 'Bandwidth': 9.11},
#  {'NameHost': 'h3', 'Bandwidth': 9.21},
#  {'NameHost': 'h3', 'Bandwidth': 8.98},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 235.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 200.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 7.59},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.21},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 58.8},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.42},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 35.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.41},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 35.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.46},
#  {'NameHost': 'h3', 'Bandwidth': 58.8},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 58.8},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.14},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.41},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.44},
#  {'NameHost': 'h3', 'Bandwidth': 58.8},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.42},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 23.5},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.42},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.44},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.21},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.41},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.44},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.5},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.42},
#  {'NameHost': 'h3', 'Bandwidth': 35.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.42},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 35.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.41},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 35.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.43},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 4.75},
#  {'NameHost': 'h3', 'Bandwidth': 2.85},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 212.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 212.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.2},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 247.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 212.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 235.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.2},
#  {'NameHost': 'h3', 'Bandwidth': 247.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.11},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 282.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.21},
#  {'NameHost': 'h3', 'Bandwidth': 212.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 318.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 259.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.16},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 270.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 270.0},
#  {'NameHost': 'h3', 'Bandwidth': 6.75},
#  {'NameHost': 'h3', 'Bandwidth': 4.37},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.46},
#  {'NameHost': 'h3', 'Bandwidth': 23.5},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 58.8},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.21},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.42},
#  {'NameHost': 'h3', 'Bandwidth': 58.8},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.44},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.41},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 58.8},
#  {'NameHost': 'h3', 'Bandwidth': 9.42},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 35.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.41},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.41},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.16},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 200.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 200.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.16},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.16},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.2},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.2},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.44},
#  {'NameHost': 'h3', 'Bandwidth': 23.5},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.38},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.41},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 212.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 2.11},
#  {'NameHost': 'h3', 'Bandwidth': 5.69},
#  {'NameHost': 'h3', 'Bandwidth': 9.07},
#  {'NameHost': 'h3', 'Bandwidth': 353.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 212.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.03},
#  {'NameHost': 'h3', 'Bandwidth': 318.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.17},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 200.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.21},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 282.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.21},
#  {'NameHost': 'h3', 'Bandwidth': 200.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.09},
#  {'NameHost': 'h3', 'Bandwidth': 200.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.16},
#  {'NameHost': 'h3', 'Bandwidth': 200.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.21},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.22},
#  {'NameHost': 'h3', 'Bandwidth': 235.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.21},
#  {'NameHost': 'h3', 'Bandwidth': 247.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 212.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.16},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 329.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 4.86},
#  {'NameHost': 'h3', 'Bandwidth': 6.35},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.43},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.14},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.42},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.47},
#  {'NameHost': 'h3', 'Bandwidth': 58.8},
#  {'NameHost': 'h3', 'Bandwidth': 9.41},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.43},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.21},
#  {'NameHost': 'h3', 'Bandwidth': 200.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.17},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 58.8},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 70.6},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 6.67},
#  {'NameHost': 'h3', 'Bandwidth': 906.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 212.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.18},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 235.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.14},
#  {'NameHost': 'h3', 'Bandwidth': 212.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.16},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 270.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.14},
#  {'NameHost': 'h3', 'Bandwidth': 235.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.17},
#  {'NameHost': 'h3', 'Bandwidth': 212.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.2},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.1},
#  {'NameHost': 'h3', 'Bandwidth': 247.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.14},
#  {'NameHost': 'h3', 'Bandwidth': 306.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.17},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 282.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.17},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 282.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.09},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 259.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 200.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.18},
#  {'NameHost': 'h3', 'Bandwidth': 200.0},
#  {'NameHost': 'h3', 'Bandwidth': 5.83},
#  {'NameHost': 'h3', 'Bandwidth': 5.35},
#  {'NameHost': 'h3', 'Bandwidth': 9.13},
#  {'NameHost': 'h3', 'Bandwidth': 294.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.1},
#  {'NameHost': 'h3', 'Bandwidth': 388.0},
#  {'NameHost': 'h3', 'Bandwidth': 235.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 9.17},
#  {'NameHost': 'h3', 'Bandwidth': 247.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 235.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.17},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.16},
#  {'NameHost': 'h3', 'Bandwidth': 235.0},
#  {'NameHost': 'h3', 'Bandwidth': 5.13},
#  {'NameHost': 'h3', 'Bandwidth': 2.58},
#  {'NameHost': 'h3', 'Bandwidth': 9.09},
#  {'NameHost': 'h3', 'Bandwidth': 412.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.07},
#  {'NameHost': 'h3', 'Bandwidth': 494.0},
#  {'NameHost': 'h3', 'Bandwidth': 8.74},
#  {'NameHost': 'h3', 'Bandwidth': 729.0},
#  {'NameHost': 'h3', 'Bandwidth': 8.71},
#  {'NameHost': 'h3', 'Bandwidth': 670.0},
#  {'NameHost': 'h3', 'Bandwidth': 8.78},
#  {'NameHost': 'h3', 'Bandwidth': 635.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.0},
#  {'NameHost': 'h3', 'Bandwidth': 435.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.07},
#  {'NameHost': 'h3', 'Bandwidth': 353.0},
#  {'NameHost': 'h3', 'Bandwidth': 8.87},
#  {'NameHost': 'h3', 'Bandwidth': 682.0},
#  {'NameHost': 'h3', 'Bandwidth': 8.91},
#  {'NameHost': 'h3', 'Bandwidth': 494.0},
#  {'NameHost': 'h3', 'Bandwidth': 8.91},
#  {'NameHost': 'h3', 'Bandwidth': 329.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 400.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.01},
#  {'NameHost': 'h3', 'Bandwidth': 470.0},
#  {'NameHost': 'h3', 'Bandwidth': 8.75},
#  {'NameHost': 'h3', 'Bandwidth': 541.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.02},
#  {'NameHost': 'h3', 'Bandwidth': 529.0},
#  {'NameHost': 'h3', 'Bandwidth': 8.9},
#  {'NameHost': 'h3', 'Bandwidth': 435.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.01},
#  {'NameHost': 'h3', 'Bandwidth': 341.0},
#  {'NameHost': 'h3', 'Bandwidth': 8.98},
#  {'NameHost': 'h3', 'Bandwidth': 506.0},
#  {'NameHost': 'h3', 'Bandwidth': 8.9},
#  {'NameHost': 'h3', 'Bandwidth': 423.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.18},
#  {'NameHost': 'h3', 'Bandwidth': 270.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.28},
#  {'NameHost': 'h3', 'Bandwidth': 200.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.09},
#  {'NameHost': 'h3', 'Bandwidth': 376.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.14},
#  {'NameHost': 'h3', 'Bandwidth': 329.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.13},
#  {'NameHost': 'h3', 'Bandwidth': 247.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.06},
#  {'NameHost': 'h3', 'Bandwidth': 294.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.2},
#  {'NameHost': 'h3', 'Bandwidth': 212.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.16},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 282.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.08},
#  {'NameHost': 'h3', 'Bandwidth': 247.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.18},
#  {'NameHost': 'h3', 'Bandwidth': 200.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 294.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.11},
#  {'NameHost': 'h3', 'Bandwidth': 306.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.04},
#  {'NameHost': 'h3', 'Bandwidth': 388.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.29},
#  {'NameHost': 'h3', 'Bandwidth': 235.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.14},
#  {'NameHost': 'h3', 'Bandwidth': 259.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.02},
#  {'NameHost': 'h3', 'Bandwidth': 341.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.11},
#  {'NameHost': 'h3', 'Bandwidth': 223.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.13},
#  {'NameHost': 'h3', 'Bandwidth': 282.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.1},
#  {'NameHost': 'h3', 'Bandwidth': 188.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 247.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.1},
#  {'NameHost': 'h3', 'Bandwidth': 329.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 294.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 212.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.15},
#  {'NameHost': 'h3', 'Bandwidth': 235.0},
#  {'NameHost': 'h3', 'Bandwidth': 8.98},
#  {'NameHost': 'h3', 'Bandwidth': 270.0},
#  {'NameHost': 'h3', 'Bandwidth': 5.97},
#  {'NameHost': 'h3', 'Bandwidth': 5.17},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 58.8},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 58.8},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.35},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.4},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 153.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.2},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.44},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.36},
#  {'NameHost': 'h3', 'Bandwidth': 82.3},
#  {'NameHost': 'h3', 'Bandwidth': 9.41},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.31},
#  {'NameHost': 'h3', 'Bandwidth': 9.46},
#  {'NameHost': 'h3', 'Bandwidth': 47.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.23},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.26},
#  {'NameHost': 'h3', 'Bandwidth': 141.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.42},
#  {'NameHost': 'h3', 'Bandwidth': 106.0},
#  {'NameHost': 'h3', 'Bandwidth': 2.07},
#  {'NameHost': 'h3', 'Bandwidth': 5.94},
#  {'NameHost': 'h3', 'Bandwidth': 4.94},
#  {'NameHost': 'h3', 'Bandwidth': 5.03},
#  {'NameHost': 'h3', 'Bandwidth': 3.66},
#  {'NameHost': 'h3', 'Bandwidth': 6.0},
#  {'NameHost': 'h3', 'Bandwidth': 3.79},
#  {'NameHost': 'h3', 'Bandwidth': 5.52},
#  {'NameHost': 'h3', 'Bandwidth': 3.85},
#  {'NameHost': 'h3', 'Bandwidth': 5.68},
#  {'NameHost': 'h3', 'Bandwidth': 3.07},
#  {'NameHost': 'h3', 'Bandwidth': 6.42},
#  {'NameHost': 'h3', 'Bandwidth': 4.15},
#  {'NameHost': 'h3', 'Bandwidth': 5.27},
#  {'NameHost': 'h3', 'Bandwidth': 3.92},
#  {'NameHost': 'h3', 'Bandwidth': 5.52},
#  {'NameHost': 'h3', 'Bandwidth': 3.36},
#  {'NameHost': 'h3', 'Bandwidth': 6.33},
#  {'NameHost': 'h3', 'Bandwidth': 6.35},
#  {'NameHost': 'h3', 'Bandwidth': 2.74},
#  {'NameHost': 'h3', 'Bandwidth': 3.07},
#  {'NameHost': 'h3', 'Bandwidth': 6.41},
#  {'NameHost': 'h3', 'Bandwidth': 4.07},
#  {'NameHost': 'h3', 'Bandwidth': 5.0},
#  {'NameHost': 'h3', 'Bandwidth': 4.36},
#  {'NameHost': 'h3', 'Bandwidth': 5.53},
#  {'NameHost': 'h3', 'Bandwidth': 3.8},
#  {'NameHost': 'h3', 'Bandwidth': 5.64},
#  {'NameHost': 'h3', 'Bandwidth': 3.93},
#  {'NameHost': 'h3', 'Bandwidth': 5.35},
#  {'NameHost': 'h3', 'Bandwidth': 4.5},
#  {'NameHost': 'h3', 'Bandwidth': 5.37},
#  {'NameHost': 'h3', 'Bandwidth': 3.63},
#  {'NameHost': 'h3', 'Bandwidth': 5.52},
#  {'NameHost': 'h3', 'Bandwidth': 6.53},
#  {'NameHost': 'h3', 'Bandwidth': 2.9},
#  {'NameHost': 'h3', 'Bandwidth': 3.68},
#  {'NameHost': 'h3', 'Bandwidth': 5.86},
#  {'NameHost': 'h3', 'Bandwidth': 2.58},
#  {'NameHost': 'h3', 'Bandwidth': 6.95},
#  {'NameHost': 'h3', 'Bandwidth': 2.94},
#  {'NameHost': 'h3', 'Bandwidth': 6.29},
#  {'NameHost': 'h3', 'Bandwidth': 2.43},
#  {'NameHost': 'h3', 'Bandwidth': 6.89},
#  {'NameHost': 'h3', 'Bandwidth': 3.5},
#  {'NameHost': 'h3', 'Bandwidth': 6.15},
#  {'NameHost': 'h3', 'Bandwidth': 3.82},
#  {'NameHost': 'h3', 'Bandwidth': 5.32},
#  {'NameHost': 'h3', 'Bandwidth': 8.04},
#  {'NameHost': 'h3', 'Bandwidth': 2.27},
#  {'NameHost': 'h3', 'Bandwidth': 9.33},
#  {'NameHost': 'h3', 'Bandwidth': 165.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 129.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.27},
#  {'NameHost': 'h3', 'Bandwidth': 9.3},
#  {'NameHost': 'h3', 'Bandwidth': 176.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.53},
#  {'NameHost': 'h3', 'Bandwidth': 11.8},
#  {'NameHost': 'h3', 'Bandwidth': 9.37},
#  {'NameHost': 'h3', 'Bandwidth': 118.0},
#  {'NameHost': 'h3', 'Bandwidth': 9.34},
#  {'NameHost': 'h3', 'Bandwidth': 94.1},
#  {'NameHost': 'h3', 'Bandwidth': 9.24},
#  {'NameHost': 'h3', 'Bandwidth': 259.0},
#  {'NameHost': 'h3', 'Bandwidth': 8.87},
#  {'NameHost': 'h3', 'Bandwidth': 459.0},
#  ...]

# %%
BW_server.insert_data(list_BW)
# Out:
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# <ipython-input-9-a15682abbcd9> in <module>
# ----> 1 BW_server.insert_data(list_BW)
#
# ~/Downloads/flaskSDN/flaskAPI/model/BW_server.py in insert_data(data_list)
#
# ~/.local/lib/python3.6/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     613         blk = _Bulk(self, ordered, bypass_document_validation)
#     614         blk.ops = [doc for doc in gen()]
# --> 615         blk.execute(write_concern, session=session)
#     616         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     617
#
# ~/.local/lib/python3.6/site-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     457                 self.execute_no_results(sock_info, generator)
#     458         else:
# --> 459             return self.execute_command(generator, write_concern, session)
#
# ~/.local/lib/python3.6/site-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     350         client = self.collection.database.client
#     351         with client._tmp_session(session) as s:
# --> 352             client._retry_with_session(self.is_retryable, retryable_bulk, s, self)
#     353
#     354         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#
# ~/.local/lib/python3.6/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1272             retryable and self.options.retry_writes and session and not session.in_transaction
#    1273         )
# -> 1274         return self._retry_internal(retryable, func, session, bulk)
#    1275
#    1276     def _retry_internal(self, retryable, func, session, bulk):
#
# ~/.local/lib/python3.6/site-packages/pymongo/mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1293         while True:
#    1294             try:
# -> 1295                 server = self._select_server(writable_server_selector, session)
#    1296                 supports_session = (
#    1297                     session is not None and server.description.retryable_writes_supported
#
# ~/.local/lib/python3.6/site-packages/pymongo/mongo_client.py in _select_server(self, server_selector, session, address)
#    1164         """
#    1165         try:
# -> 1166             topology = self._get_topology()
#    1167             if session and not session.in_transaction:
#    1168                 session._transaction.reset()
#
# ~/.local/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_topology(self)
#    1121         launches the connection process in the background.
#    1122         """
# -> 1123         self._topology.open()
#    1124         with self.__lock:
#    1125             self._kill_cursors_executor.open()
#
# ~/.local/lib/python3.6/site-packages/pymongo/topology.py in open(self)
#     182
#     183         with self._lock:
# --> 184             self._ensure_opened()
#     185
#     186     def select_servers(self, selector, server_selection_timeout=None, address=None):
#
# ~/.local/lib/python3.6/site-packages/pymongo/topology.py in _ensure_opened(self)
#     561         """
#     562         if self._closed:
# --> 563             raise InvalidOperation("Cannot use MongoClient after close")
#     564
#     565         if not self._opened:
#
# InvalidOperation: Cannot use MongoClient after close

# %%
# convert numpy 2D to dataframe
pd.DataFrame(df_final, columns=['Transfer', 'Bandwidth', 'Jitter', 'Lost', 'Total', 'Datagrams'])
# Out:
#       Transfer  Bandwidth  Jitter    Lost   Total  Datagrams
# 0       655.00       5.36   0.020    10.0   466.0        2.1
# 1         1.02       8.56   0.010    24.0   752.0        3.2
# 2         1.02       8.55   0.135    19.0   746.0        2.5
# 3         1.01       8.43   0.011    36.0   753.0        4.8
# 4         1.03       8.67   1.183    26.0   763.0        3.4
# ...        ...        ...     ...     ...     ...        ...
# 1475      4.31      35.30   6.728   729.0   732.0      100.0
# 1476      1.14       9.55   0.715   618.0  1430.0       43.0
# 1477     14.40     118.00  68.988  5746.0  5756.0      100.0
# 1478      1.13       9.49   0.677   621.0  1428.0       43.0
# 1479     11.50      94.10  90.606   481.0   489.0       98.0
#
# [1480 rows x 6 columns]

# %%
#duong di den server 1 + gia tri hien tai cua server 1 = X 
a = [124.5, 5.6, 6.7, 7.8, 8.9]
a[2] = "tuan"
a
# Out:
# [124.5, 5.6, 'tuan', 7.8, 8.9]
